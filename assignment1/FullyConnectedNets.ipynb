# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cs231n/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from before. For right now, don't worry about implementing dropout or batch/layer normalization yet, as you will add those features later.

# %%
# Setup cell.
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# /home/sunflower/CS231n/assignment1/cs231n/data_utils.py:16: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   return pickle.load(f, encoding="latin1")
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  2.300479089768492
# W1 relative error: 1.0252674471656573e-07
# W2 relative error: 2.2120479295080622e-05
# W3 relative error: 4.5623278736665505e-07
# b1 relative error: 4.6600944653202505e-09
# b2 relative error: 2.085654276112763e-09
# b3 relative error: 1.689724888469736e-10
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 3.904541941902138e-09
# W2 relative error: 6.86942277940646e-08
# W3 relative error: 3.483989247437803e-08
# b1 relative error: 1.4752427965311745e-08
# b2 relative error: 1.4615869332918208e-09
# b3 relative error: 1.3200479211447775e-10

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# Use a three-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

weight_scale = 2e-2  # Experiment with this!
learning_rate = 1e-2  # Experiment with this!


model = FullyConnectedNet(
    [100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule="sgd",
    optim_config={"learning_rate": learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title("Training loss history")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 3.604568
# (Epoch 0 / 20) train acc: 0.220000; val_acc: 0.121000
# (Epoch 1 / 20) train acc: 0.360000; val_acc: 0.130000
# (Epoch 2 / 20) train acc: 0.640000; val_acc: 0.173000
# (Epoch 3 / 20) train acc: 0.780000; val_acc: 0.199000
# (Epoch 4 / 20) train acc: 0.900000; val_acc: 0.190000
# (Epoch 5 / 20) train acc: 0.900000; val_acc: 0.194000
# (Iteration 11 / 40) loss: 0.189322
# (Epoch 6 / 20) train acc: 0.900000; val_acc: 0.187000
# (Epoch 7 / 20) train acc: 0.940000; val_acc: 0.187000
# (Epoch 8 / 20) train acc: 0.960000; val_acc: 0.186000
# (Epoch 9 / 20) train acc: 1.000000; val_acc: 0.183000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.175000
# (Iteration 21 / 40) loss: 0.081366
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.179000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.180000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.176000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.170000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.174000
# (Iteration 31 / 40) loss: 0.020267
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.185000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.181000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.173000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.177000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.177000

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# Use a five-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = [1e-3, 5e-4, 1e-4]  # Experiment with this!
weight_scale = [1e-2, 5e-3, 1e-3]  # Experiment with this!

for w in weight_scale:
    for lr in learning_rate:
        model = FullyConnectedNet(
            [100, 500, 500, 100],
            weight_scale=w,
            dtype=np.float64
        )
        solver = Solver(
            model,
            small_data,
            print_every=10,
            num_epochs=20,
            batch_size=25,
            update_rule='sgd',
            optim_config={'learning_rate': lr},
        )
        solver.train()

        plt.plot(solver.loss_history)
        plt.title('Training loss history')
        plt.xlabel('Iteration')
        plt.ylabel('Training loss')
        plt.grid(linestyle='--', linewidth=0.5)
        plt.show()
# Out:
# (Iteration 1 / 40) loss: 2.302086
# (Epoch 0 / 20) train acc: 0.060000; val_acc: 0.084000
# (Epoch 1 / 20) train acc: 0.060000; val_acc: 0.085000
# (Epoch 2 / 20) train acc: 0.060000; val_acc: 0.085000
# (Epoch 3 / 20) train acc: 0.060000; val_acc: 0.084000
# (Epoch 4 / 20) train acc: 0.060000; val_acc: 0.082000
# (Epoch 5 / 20) train acc: 0.060000; val_acc: 0.075000
# (Iteration 11 / 40) loss: 2.303345
# (Epoch 6 / 20) train acc: 0.060000; val_acc: 0.076000
# (Epoch 7 / 20) train acc: 0.060000; val_acc: 0.080000
# (Epoch 8 / 20) train acc: 0.060000; val_acc: 0.080000
# (Epoch 9 / 20) train acc: 0.060000; val_acc: 0.081000
# (Epoch 10 / 20) train acc: 0.060000; val_acc: 0.082000
# (Iteration 21 / 40) loss: 2.302842
# (Epoch 11 / 20) train acc: 0.060000; val_acc: 0.088000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.084000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.086000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.084000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.088000
# (Iteration 31 / 40) loss: 2.300810
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.091000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.089000
# (Epoch 18 / 20) train acc: 0.100000; val_acc: 0.083000
# (Epoch 19 / 20) train acc: 0.100000; val_acc: 0.084000
# (Epoch 20 / 20) train acc: 0.100000; val_acc: 0.086000
# (Iteration 1 / 40) loss: 2.302844
# (Epoch 0 / 20) train acc: 0.080000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.080000; val_acc: 0.078000
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.080000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.080000
# (Epoch 4 / 20) train acc: 0.080000; val_acc: 0.078000
# (Epoch 5 / 20) train acc: 0.080000; val_acc: 0.079000
# (Iteration 11 / 40) loss: 2.299937
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.082000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.081000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.080000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.080000
# (Epoch 10 / 20) train acc: 0.100000; val_acc: 0.081000
# (Iteration 21 / 40) loss: 2.301447
# (Epoch 11 / 20) train acc: 0.100000; val_acc: 0.083000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.081000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.081000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.081000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.081000
# (Iteration 31 / 40) loss: 2.299992
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.083000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.083000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.084000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.085000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.080000
# (Iteration 1 / 40) loss: 2.302984
# (Epoch 0 / 20) train acc: 0.080000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.080000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.110000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.110000
# (Epoch 4 / 20) train acc: 0.080000; val_acc: 0.112000
# (Epoch 5 / 20) train acc: 0.080000; val_acc: 0.112000
# (Iteration 11 / 40) loss: 2.302391
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.112000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.111000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.111000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.111000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.112000
# (Iteration 21 / 40) loss: 2.301978
# (Epoch 11 / 20) train acc: 0.100000; val_acc: 0.111000
# (Epoch 12 / 20) train acc: 0.100000; val_acc: 0.111000
# (Epoch 13 / 20) train acc: 0.100000; val_acc: 0.110000
# (Epoch 14 / 20) train acc: 0.100000; val_acc: 0.110000
# (Epoch 15 / 20) train acc: 0.120000; val_acc: 0.110000
# (Iteration 31 / 40) loss: 2.302594
# (Epoch 16 / 20) train acc: 0.120000; val_acc: 0.111000
# (Epoch 17 / 20) train acc: 0.120000; val_acc: 0.111000
# (Epoch 18 / 20) train acc: 0.120000; val_acc: 0.111000
# (Epoch 19 / 20) train acc: 0.120000; val_acc: 0.111000
# (Epoch 20 / 20) train acc: 0.120000; val_acc: 0.112000
# (Iteration 1 / 40) loss: 2.302547
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.096000
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.083000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.109000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.109000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 11 / 40) loss: 2.302485
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 21 / 40) loss: 2.302407
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 31 / 40) loss: 2.302036
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 1 / 40) loss: 2.302590
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.106000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.109000
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.112000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.136000
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.120000
# (Iteration 11 / 40) loss: 2.302513
# (Epoch 6 / 20) train acc: 0.180000; val_acc: 0.115000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.113000
# (Iteration 21 / 40) loss: 2.302374
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.180000; val_acc: 0.103000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.111000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.113000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 31 / 40) loss: 2.302490
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.113000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.113000
# (Epoch 20 / 20) train acc: 0.180000; val_acc: 0.105000
# (Iteration 1 / 40) loss: 2.302603
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.116000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.117000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.103000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.105000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.107000
# (Iteration 11 / 40) loss: 2.302534
# (Epoch 6 / 20) train acc: 0.180000; val_acc: 0.106000
# (Epoch 7 / 20) train acc: 0.200000; val_acc: 0.107000
# (Epoch 8 / 20) train acc: 0.240000; val_acc: 0.111000
# (Epoch 9 / 20) train acc: 0.240000; val_acc: 0.111000
# (Epoch 10 / 20) train acc: 0.240000; val_acc: 0.107000
# (Iteration 21 / 40) loss: 2.302565
# (Epoch 11 / 20) train acc: 0.240000; val_acc: 0.109000
# (Epoch 12 / 20) train acc: 0.220000; val_acc: 0.105000
# (Epoch 13 / 20) train acc: 0.220000; val_acc: 0.108000
# (Epoch 14 / 20) train acc: 0.220000; val_acc: 0.101000
# (Epoch 15 / 20) train acc: 0.220000; val_acc: 0.105000
# (Iteration 31 / 40) loss: 2.302529
# (Epoch 16 / 20) train acc: 0.220000; val_acc: 0.101000
# (Epoch 17 / 20) train acc: 0.220000; val_acc: 0.103000
# (Epoch 18 / 20) train acc: 0.240000; val_acc: 0.103000
# (Epoch 19 / 20) train acc: 0.200000; val_acc: 0.113000
# (Epoch 20 / 20) train acc: 0.220000; val_acc: 0.114000
# (Iteration 1 / 40) loss: 2.302585
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 11 / 40) loss: 2.302376
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 21 / 40) loss: 2.302117
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 31 / 40) loss: 2.302279
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 1 / 40) loss: 2.302585
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 11 / 40) loss: 2.302555
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.095000
# (Iteration 21 / 40) loss: 2.302424
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 31 / 40) loss: 2.302246
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 1 / 40) loss: 2.302585
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.074000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.103000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 11 / 40) loss: 2.302569
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 21 / 40) loss: 2.302537
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 31 / 40) loss: 2.302573
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.112000

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
# [FILL THIS IN]

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-4},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")

for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  sgd
# (Iteration 1 / 200) loss: 2.585053
# (Epoch 0 / 5) train acc: 0.099000; val_acc: 0.099000
# (Iteration 11 / 200) loss: 2.635342
# (Iteration 21 / 200) loss: 2.406801
# (Iteration 31 / 200) loss: 2.254871
# (Epoch 1 / 5) train acc: 0.142000; val_acc: 0.134000
# (Iteration 41 / 200) loss: 2.302966
# (Iteration 51 / 200) loss: 2.344576
# (Iteration 61 / 200) loss: 2.286417
# (Iteration 71 / 200) loss: 2.255951
# (Epoch 2 / 5) train acc: 0.150000; val_acc: 0.143000
# (Iteration 81 / 200) loss: 2.296242
# (Iteration 91 / 200) loss: 2.271478
# (Iteration 101 / 200) loss: 2.232300
# (Iteration 111 / 200) loss: 2.307345
# (Epoch 3 / 5) train acc: 0.180000; val_acc: 0.166000
# (Iteration 121 / 200) loss: 2.336200
# (Iteration 131 / 200) loss: 2.216017
# (Iteration 141 / 200) loss: 2.228946
# (Iteration 151 / 200) loss: 2.337956
# (Epoch 4 / 5) train acc: 0.188000; val_acc: 0.171000
# (Iteration 161 / 200) loss: 2.291814
# (Iteration 171 / 200) loss: 2.155659
# (Iteration 181 / 200) loss: 2.264818
# (Iteration 191 / 200) loss: 2.134118
# (Epoch 5 / 5) train acc: 0.197000; val_acc: 0.182000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 2.418510
# (Epoch 0 / 5) train acc: 0.098000; val_acc: 0.113000
# (Iteration 11 / 200) loss: 2.256965
# (Iteration 21 / 200) loss: 2.236716
# (Iteration 31 / 200) loss: 2.202482
# (Epoch 1 / 5) train acc: 0.211000; val_acc: 0.230000
# (Iteration 41 / 200) loss: 2.111977
# (Iteration 51 / 200) loss: 2.069004
# (Iteration 61 / 200) loss: 2.041209
# (Iteration 71 / 200) loss: 2.025944
# (Epoch 2 / 5) train acc: 0.289000; val_acc: 0.268000
# (Iteration 81 / 200) loss: 1.925268
# (Iteration 91 / 200) loss: 1.985571
# (Iteration 101 / 200) loss: 1.886910
# (Iteration 111 / 200) loss: 1.936661
# (Epoch 3 / 5) train acc: 0.331000; val_acc: 0.303000
# (Iteration 121 / 200) loss: 1.774217
# (Iteration 131 / 200) loss: 1.759546
# (Iteration 141 / 200) loss: 1.853215
# (Iteration 151 / 200) loss: 2.002690
# (Epoch 4 / 5) train acc: 0.344000; val_acc: 0.301000
# (Iteration 161 / 200) loss: 1.753756
# (Iteration 171 / 200) loss: 1.852521
# (Iteration 181 / 200) loss: 1.848170
# (Iteration 191 / 200) loss: 1.840004
# (Epoch 5 / 5) train acc: 0.355000; val_acc: 0.326000

# %% [markdown]
# ## RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.524687511038133e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  1.1395691798535431e-07
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )
    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': learning_rates[update_rule]},
        verbose=True
    )
    solvers[update_rule] = solver
    solver.train()
    print()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"{update_rule}")

for ax in axes:
    ax.legend(loc='best', ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  adam
# (Iteration 1 / 200) loss: 3.237968
# (Epoch 0 / 5) train acc: 0.124000; val_acc: 0.101000
# (Iteration 11 / 200) loss: 2.085587
# (Iteration 21 / 200) loss: 2.146130
# (Iteration 31 / 200) loss: 1.941587
# (Epoch 1 / 5) train acc: 0.340000; val_acc: 0.319000
# (Iteration 41 / 200) loss: 1.801444
# (Iteration 51 / 200) loss: 1.840495
# (Iteration 61 / 200) loss: 1.714258
# (Iteration 71 / 200) loss: 1.485308
# (Epoch 2 / 5) train acc: 0.426000; val_acc: 0.375000
# (Iteration 81 / 200) loss: 1.745236
# (Iteration 91 / 200) loss: 1.501541
# (Iteration 101 / 200) loss: 1.596477
# (Iteration 111 / 200) loss: 1.442988
# (Epoch 3 / 5) train acc: 0.462000; val_acc: 0.315000
# (Iteration 121 / 200) loss: 1.553437
# (Iteration 131 / 200) loss: 1.359854
# (Iteration 141 / 200) loss: 1.587787
# (Iteration 151 / 200) loss: 1.323951
# (Epoch 4 / 5) train acc: 0.504000; val_acc: 0.378000
# (Iteration 161 / 200) loss: 1.372490
# (Iteration 171 / 200) loss: 1.164883
# (Iteration 181 / 200) loss: 1.246284
# (Iteration 191 / 200) loss: 1.262266
# (Epoch 5 / 5) train acc: 0.587000; val_acc: 0.350000
#
# Running with  rmsprop
# (Iteration 1 / 200) loss: 2.955560
# (Epoch 0 / 5) train acc: 0.153000; val_acc: 0.138000
# (Iteration 11 / 200) loss: 2.140125
# (Iteration 21 / 200) loss: 1.958255
# (Iteration 31 / 200) loss: 1.908087
# (Epoch 1 / 5) train acc: 0.356000; val_acc: 0.284000
# (Iteration 41 / 200) loss: 1.960579
# (Iteration 51 / 200) loss: 1.832611
# (Iteration 61 / 200) loss: 1.818779
# (Iteration 71 / 200) loss: 1.632450
# (Epoch 2 / 5) train acc: 0.443000; val_acc: 0.326000
# (Iteration 81 / 200) loss: 1.702117
# (Iteration 91 / 200) loss: 1.719338
# (Iteration 101 / 200) loss: 1.698766
# (Iteration 111 / 200) loss: 1.527510
# (Epoch 3 / 5) train acc: 0.464000; val_acc: 0.340000
# (Iteration 121 / 200) loss: 1.621801
# (Iteration 131 / 200) loss: 1.731728
# (Iteration 141 / 200) loss: 1.586149
# (Iteration 151 / 200) loss: 1.309237
# (Epoch 4 / 5) train acc: 0.514000; val_acc: 0.326000
# (Iteration 161 / 200) loss: 1.454224
# (Iteration 171 / 200) loss: 1.471945
# (Iteration 181 / 200) loss: 1.422866
# (Iteration 191 / 200) loss: 1.484471
# (Epoch 5 / 5) train acc: 0.574000; val_acc: 0.356000

# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
# [FILL THIS IN]

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the next assignment, we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional networks rather than fully connected networks.
#
# **Note:** In the next assignment, you will learn techniques like BatchNormalization and Dropout which can help you train powerful models.

# %%
best_model = None
################################################################################
# Train the best FullyConnectedNet that you can on CIFAR-10. You might         #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
learning_rates = [1e-3]
hidden_dims = [[100, 80, 50]]
regs = [5e-3]
weight_scales = [1e-3]

for lr in learning_rates:
    for hd in hidden_dims:
        for reg in regs:
            for ws in  weight_scales:
                model = FullyConnectedNet(hd, reg=reg, weight_scale=ws)
                solver = Solver(model, data, update_rule="adam", optim_config={"learning_rate": lr}, lr_decay=0.95, num_epochs=80, batch_size=512, print_every=1000)
                solver.train()
                best_model = model
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (Iteration 1 / 7600) loss: 2.303387
# (Epoch 0 / 80) train acc: 0.086000; val_acc: 0.113000
# (Epoch 1 / 80) train acc: 0.267000; val_acc: 0.285000
# (Epoch 2 / 80) train acc: 0.407000; val_acc: 0.409000
# (Epoch 3 / 80) train acc: 0.436000; val_acc: 0.445000
# (Epoch 4 / 80) train acc: 0.501000; val_acc: 0.485000
# (Epoch 5 / 80) train acc: 0.504000; val_acc: 0.494000
# (Epoch 6 / 80) train acc: 0.525000; val_acc: 0.506000
# (Epoch 7 / 80) train acc: 0.543000; val_acc: 0.504000
# (Epoch 8 / 80) train acc: 0.558000; val_acc: 0.520000
# (Epoch 9 / 80) train acc: 0.588000; val_acc: 0.521000
# (Epoch 10 / 80) train acc: 0.573000; val_acc: 0.523000
# (Iteration 1001 / 7600) loss: 1.232206
# (Epoch 11 / 80) train acc: 0.594000; val_acc: 0.533000
# (Epoch 12 / 80) train acc: 0.605000; val_acc: 0.549000
# (Epoch 13 / 80) train acc: 0.599000; val_acc: 0.532000
# (Epoch 14 / 80) train acc: 0.623000; val_acc: 0.530000
# (Epoch 15 / 80) train acc: 0.635000; val_acc: 0.525000
# (Epoch 16 / 80) train acc: 0.626000; val_acc: 0.535000
# (Epoch 17 / 80) train acc: 0.646000; val_acc: 0.547000
# (Epoch 18 / 80) train acc: 0.668000; val_acc: 0.535000
# (Epoch 19 / 80) train acc: 0.656000; val_acc: 0.525000
# (Epoch 20 / 80) train acc: 0.677000; val_acc: 0.534000
# (Epoch 21 / 80) train acc: 0.669000; val_acc: 0.518000
# (Iteration 2001 / 7600) loss: 1.005494
# (Epoch 22 / 80) train acc: 0.707000; val_acc: 0.542000
# (Epoch 23 / 80) train acc: 0.656000; val_acc: 0.529000
# (Epoch 24 / 80) train acc: 0.693000; val_acc: 0.524000
# (Epoch 25 / 80) train acc: 0.691000; val_acc: 0.528000
# (Epoch 26 / 80) train acc: 0.715000; val_acc: 0.529000
# (Epoch 27 / 80) train acc: 0.731000; val_acc: 0.528000
# (Epoch 28 / 80) train acc: 0.735000; val_acc: 0.520000
# (Epoch 29 / 80) train acc: 0.727000; val_acc: 0.519000
# (Epoch 30 / 80) train acc: 0.747000; val_acc: 0.541000
# (Epoch 31 / 80) train acc: 0.771000; val_acc: 0.515000
# (Iteration 3001 / 7600) loss: 0.937628
# (Epoch 32 / 80) train acc: 0.765000; val_acc: 0.534000
# (Epoch 33 / 80) train acc: 0.747000; val_acc: 0.530000
# (Epoch 34 / 80) train acc: 0.752000; val_acc: 0.523000
# (Epoch 35 / 80) train acc: 0.748000; val_acc: 0.532000
# (Epoch 36 / 80) train acc: 0.762000; val_acc: 0.524000
# (Epoch 37 / 80) train acc: 0.781000; val_acc: 0.524000
# (Epoch 38 / 80) train acc: 0.772000; val_acc: 0.541000
# (Epoch 39 / 80) train acc: 0.784000; val_acc: 0.529000
# (Epoch 40 / 80) train acc: 0.814000; val_acc: 0.529000
# (Epoch 41 / 80) train acc: 0.803000; val_acc: 0.525000
# (Epoch 42 / 80) train acc: 0.806000; val_acc: 0.525000
# (Iteration 4001 / 7600) loss: 0.678490
# (Epoch 43 / 80) train acc: 0.815000; val_acc: 0.530000
# (Epoch 44 / 80) train acc: 0.814000; val_acc: 0.521000
# (Epoch 45 / 80) train acc: 0.840000; val_acc: 0.522000
# (Epoch 46 / 80) train acc: 0.811000; val_acc: 0.512000
# (Epoch 47 / 80) train acc: 0.833000; val_acc: 0.522000
# (Epoch 48 / 80) train acc: 0.840000; val_acc: 0.529000
# (Epoch 49 / 80) train acc: 0.815000; val_acc: 0.539000
# (Epoch 50 / 80) train acc: 0.831000; val_acc: 0.531000
# (Epoch 51 / 80) train acc: 0.847000; val_acc: 0.526000
# (Epoch 52 / 80) train acc: 0.831000; val_acc: 0.524000
# (Iteration 5001 / 7600) loss: 0.732493
# (Epoch 53 / 80) train acc: 0.854000; val_acc: 0.520000
# (Epoch 54 / 80) train acc: 0.849000; val_acc: 0.527000
# (Epoch 55 / 80) train acc: 0.860000; val_acc: 0.528000
# (Epoch 56 / 80) train acc: 0.864000; val_acc: 0.533000
# (Epoch 57 / 80) train acc: 0.839000; val_acc: 0.523000
# (Epoch 58 / 80) train acc: 0.845000; val_acc: 0.529000
# (Epoch 59 / 80) train acc: 0.859000; val_acc: 0.514000
# (Epoch 60 / 80) train acc: 0.865000; val_acc: 0.521000
# (Epoch 61 / 80) train acc: 0.866000; val_acc: 0.518000
# (Epoch 62 / 80) train acc: 0.900000; val_acc: 0.520000
# (Epoch 63 / 80) train acc: 0.877000; val_acc: 0.521000
# (Iteration 6001 / 7600) loss: 0.559058
# (Epoch 64 / 80) train acc: 0.885000; val_acc: 0.522000
# (Epoch 65 / 80) train acc: 0.862000; val_acc: 0.520000
# (Epoch 66 / 80) train acc: 0.891000; val_acc: 0.515000
# (Epoch 67 / 80) train acc: 0.891000; val_acc: 0.523000
# (Epoch 68 / 80) train acc: 0.870000; val_acc: 0.523000
# (Epoch 69 / 80) train acc: 0.880000; val_acc: 0.522000
# (Epoch 70 / 80) train acc: 0.888000; val_acc: 0.522000
# (Epoch 71 / 80) train acc: 0.886000; val_acc: 0.521000
# (Epoch 72 / 80) train acc: 0.857000; val_acc: 0.526000
# (Epoch 73 / 80) train acc: 0.857000; val_acc: 0.518000
# (Iteration 7001 / 7600) loss: 0.524951
# (Epoch 74 / 80) train acc: 0.897000; val_acc: 0.523000
# (Epoch 75 / 80) train acc: 0.880000; val_acc: 0.520000
# (Epoch 76 / 80) train acc: 0.889000; val_acc: 0.516000
# (Epoch 77 / 80) train acc: 0.876000; val_acc: 0.523000
# (Epoch 78 / 80) train acc: 0.881000; val_acc: 0.517000
# (Epoch 79 / 80) train acc: 0.884000; val_acc: 0.516000
# (Epoch 80 / 80) train acc: 0.878000; val_acc: 0.511000

# %% [markdown]
# # Test Your Model!
# Run your best model on the validation and test sets. You should achieve at least 50% accuracy on the validation set and the test set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.549
# Test set accuracy:  0.52
